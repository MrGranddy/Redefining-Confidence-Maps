# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
conf1 = "C:/Users/Bugra/Desktop/masters-thesis/final_data/karamalis/spine/full/conf_map.npy"
conf2 = "C:/Users/Bugra/Desktop/masters-thesis/final_data/ultranerf/spine/full/conf_map.npy"
us = "C:/Users/Bugra/Desktop/masters-thesis/final_data/original/spine/images.npy"

conf1 = np.load(conf1)
conf2 = np.load(conf2)
us = np.load(us)

# %%
print(conf1.shape)
print(conf2.shape)
print(us.shape)
# Out:
# (2389, 1300, 164)
# (2389, 1300, 164)
# (2389, 1300, 164)

# %%
random_slice = 900

# %%
plt.figure(figsize=(10, 8))

plt.subplot(1, 3, 1)
plt.imshow(conf1[random_slice])
plt.title("Karamalis")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(conf2[random_slice])
plt.title("Ultranerf")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(us[random_slice])
plt.title("Ultrasound")
plt.colorbar()

plt.show()
